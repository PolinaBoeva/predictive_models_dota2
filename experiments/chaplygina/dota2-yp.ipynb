# %% [markdown]
# # Предсказательные модели для Dota 2

# %% [markdown]
# Проект разработки сервиса, который по ID матча выдает вероятность победы той или иной команды в Dota 2, а также строит различные сегментационные карты (хитмапы) по результатам игры.

# %% [markdown]
# **Участники:**
# * Боева Полина Викторовна — @Boeva_pv, PolinaBoeva
# * Бородачев Сергей Игоревич — @RaiFox, Rai-Fox
# * Герилович Илья Павлович — @mrbrainers, ilyager99
# * Чаплыгина Арина Сергеевна — @chaarse, chaarse
#
# **Куратор:** Макарова Мария - @mariagolddd

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Шаг 1. Сбор данных

# %%
match = {}
for i in range(1, 10):
    key = f'm{i}'
    file_path = f'/kaggle/input/dota-2-pro-league-matches-2023/20240{i}/main_metadata.csv'
    match[key] = pd.read_csv(file_path)

key = 'd10'
file_path = '/kaggle/input/dota-2-pro-league-matches-2023/202410/main_metadata.csv'
match[key] = pd.read_csv(file_path)


players = {}
for i in range(1, 10):
    key = f'p{i}'
    file_path = f'/kaggle/input/dota-2-pro-league-matches-2023/20240{i}/players.csv'
    players[key] = pd.read_csv(file_path, dtype='str')

key = 'd10'
file_path = '/kaggle/input/dota-2-pro-league-matches-2023/202410/players.csv'
players[key] = pd.read_csv(file_path)

# %%
match_df = pd.concat(match.values(), ignore_index=True)
players_df = pd.concat(players.values(), ignore_index=True)

# %%
match_df.drop(columns=['Unnamed: 0'], inplace=True)
players_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
match_df.head()
# Out:
#      match_id barracks_status_dire barracks_status_radiant  cluster  \
# 0  7515635423           '00110100'              '00111111'      274
# 1  7515660161           '00111111'              '00001111'      273
# 2  7515737711           '00111101'              '00111111'      271
# 3  7515745579           '00110011'              '00111111'      272
# 4  7515769503           '00111111'              '00000000'      153
#
#    dire_score  duration  engine  first_blood_time  game_mode  human_players  \
# 0          26      1926       1               140          2             10
# 1          43      1731       1               121          2             10
# 2          25      2056       1                84          2             10
# 3          31      2221       1                28          2             10
# 4          21      1998       1               264          2             10
#
#    ...  radiant_team_id  pre_game_duration  flags  radiant_logo  \
# 0  ...        9048057.0               90.0    5.0  2.041868e+18
# 1  ...        8850100.0               90.0    5.0  1.908989e+18
# 2  ...        8893825.0               90.0    5.0  2.001336e+18
# 3  ...        8629324.0               90.0    5.0  2.017089e+18
# 4  ...        8736661.0               90.0    1.0  1.899975e+18
#
#    radiant_team_complete     dire_logo dire_team_complete radiant_captain  \
# 0                    1.0  1.908989e+18                1.0    1.770622e+08
# 1                    1.0  2.041868e+18                1.0    8.408596e+08
# 2                    0.0  2.152217e+18                0.0    1.459124e+09
# 3                    1.0  2.036224e+18                1.0    1.173255e+09
# 4                    0.0  1.831290e+18                0.0    1.363522e+08
#
#    dire_captain average_rank
# 0  1.773383e+08          NaN
# 1  2.942451e+08          NaN
# 2  1.459382e+09          NaN
# 3  9.486598e+08          NaN
# 4  1.542238e+08          NaN
#
# [5 rows x 42 columns]

# %%
players_df.head()
# Out:
#      match_id player_slot                                    ability_targets  \
# 0  7515635423           0  {'earth_spirit_boulder_smash': {'npc_dota_hero...
# 1  7515635423           1  {'morphling_adaptive_strike_agi': {'npc_dota_h...
# 2  7515635423           2  {'shadow_demon_disruption': {'npc_dota_hero_lu...
# 3  7515635423           3  {'treant_leech_seed': {'npc_dota_hero_lion': 1...
# 4  7515635423           4                                                 {}
#
#                                 ability_upgrades_arr  \
# 0  [5608, 5609, 5608, 5609, 5608, 5612, 5608, 560...
# 1  [5055, 5053, 5053, 5052, 5053, 5057, 5053, 505...
# 2  [5421, 5423, 5423, 5421, 5423, 5425, 5423, 542...
# 3  [5435, 338, 5435, 338, 5435, 5437, 5435, 338, ...
# 4  [5062, 5059, 5062, 5059, 5059, 5062, 5059, 506...
#
#                                         ability_uses   account_id  \
# 0  {'seasonal_party_hat': 1, 'earth_spirit_stone_...  177062248.0
# 1  {'seasonal_party_hat': 1, 'morphling_morph_agi...  164322994.0
# 2  {'ability_lamp_use': 3, 'shadow_demon_shadow_p...  294245092.0
# 3  {'treant_leech_seed': 34, 'treant_natures_gras...  154357932.0
# 4  {'ability_lamp_use': 2, 'nevermore_shadowraze2...  279486190.0
#
#                                              actions additional_units assists  \
# 0  {'1': 7175, '2': 13, '3': 15, '4': 1733, '5': ...              NaN    21.0
# 1  {'1': 7336, '2': 10, '3': 49, '4': 1017, '5': ...              NaN     6.0
# 2  {'1': 5860, '2': 64, '3': 25, '4': 618, '5': 1...              NaN    18.0
# 3  {'1': 8202, '2': 121, '3': 14, '4': 458, '5': ...              NaN    19.0
# 4  {'1': 4417, '2': 13, '4': 2226, '5': 11, '6': ...              NaN     4.0
#
#   backpack_0  ... purchase_rapier observers_placed  \
# 0        0.0  ...             NaN              0.0
# 1       16.0  ...             NaN              0.0
# 2        0.0  ...             NaN              4.0
# 3       16.0  ...             NaN              7.0
# 4        0.0  ...             NaN              2.0
#
#                                              healing team_number team_slot  \
# 0  {'npc_dota_hero_earth_spirit': 2641, 'npc_dota...         0.0       0.0
# 1                  {'npc_dota_hero_morphling': 3227}         0.0       1.0
# 2  {'npc_dota_hero_shadow_demon': 1156, 'npc_dota...         0.0       2.0
# 3  {'npc_dota_hero_treant': 6910, 'npc_dota_hero_...         0.0       3.0
# 4                  {'npc_dota_hero_nevermore': 1462}         0.0       4.0
#
#   aghanims_scepter aghanims_shard moonshard hero_variant neutral_tokens_log
# 0              0.0            0.0       0.0          NaN                NaN
# 1              0.0            0.0       0.0          NaN                NaN
# 2              0.0            1.0       0.0          NaN                NaN
# 3              0.0            1.0       0.0          NaN                NaN
# 4              0.0            0.0       0.0          NaN                NaN
#
# [5 rows x 150 columns]

# %% [markdown]
# ## Шаг 2. Разведочный анализ данных

# %% [markdown]
# ### Датасет *match_df*

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24704 entries, 0 to 24703
# Data columns (total 42 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   match_id                 24704 non-null  int64
#  1   barracks_status_dire     24704 non-null  object
#  2   barracks_status_radiant  24704 non-null  object
#  3   cluster                  24704 non-null  int64
#  4   dire_score               24704 non-null  int64
#  5   duration                 24704 non-null  int64
#  6   engine                   24704 non-null  int64
#  7   first_blood_time         24704 non-null  int64
#  8   game_mode                24704 non-null  int64
#  9   human_players            24704 non-null  int64
#  10  leagueid                 24704 non-null  int64
#  11  lobby_type               24704 non-null  int64
#  12  match_seq_num            24704 non-null  int64
#  13  negative_votes           0 non-null      float64
#  14  positive_votes           0 non-null      float64
#  15  radiant_score            24704 non-null  int64
#  16  radiant_win              23919 non-null  object
#  17  start_date_time          24704 non-null  object
#  18  tower_status_dire        24704 non-null  object
#  19  tower_status_radiant     24704 non-null  object
#  20  version                  24704 non-null  float64
#  21  replay_salt              24704 non-null  float64
#  22  series_id                18975 non-null  float64
#  23  series_type              18975 non-null  float64
#  24  patch                    24704 non-null  int64
#  25  region                   24149 non-null  float64
#  26  throw                    12639 non-null  float64
#  27  loss                     12639 non-null  float64
#  28  comeback                 12023 non-null  float64
#  29  stomp                    12023 non-null  float64
#  30  replay_url               24704 non-null  object
#  31  dire_team_id             23707 non-null  float64
#  32  radiant_team_id          23802 non-null  float64
#  33  pre_game_duration        24704 non-null  float64
#  34  flags                    24704 non-null  float64
#  35  radiant_logo             20559 non-null  float64
#  36  radiant_team_complete    23802 non-null  float64
#  37  dire_logo                20078 non-null  float64
#  38  dire_team_complete       23707 non-null  float64
#  39  radiant_captain          24278 non-null  float64
#  40  dire_captain             24274 non-null  float64
#  41  average_rank             0 non-null      float64
# dtypes: float64(22), int64(13), object(7)
# memory usage: 7.9+ MB

# %%
match_df.dropna(axis=1, how='all', inplace=True)

# %%
match_df.isna().sum()
# Out:
# match_id                       0
# barracks_status_dire           0
# barracks_status_radiant        0
# cluster                        0
# dire_score                     0
# duration                       0
# engine                         0
# first_blood_time               0
# game_mode                      0
# human_players                  0
# leagueid                       0
# lobby_type                     0
# match_seq_num                  0
# radiant_score                  0
# radiant_win                  785
# start_date_time                0
# tower_status_dire              0
# tower_status_radiant           0
# version                        0
# replay_salt                    0
# series_id                   5729
# series_type                 5729
# patch                          0
# region                       555
# throw                      12065
# loss                       12065
# comeback                   12681
# stomp                      12681
# replay_url                     0
# dire_team_id                 997
# radiant_team_id              902
# pre_game_duration              0
# flags                          0
# radiant_logo                4145
# radiant_team_complete        902
# dire_logo                   4626
# dire_team_complete           997
# radiant_captain              426
# dire_captain                 430
# dtype: int64

# %%
n_rows = len(match_df)
cols_with_na = match_df.columns[match_df.isna().any()] # столбцы с пропущенными значениями

plt.figure(figsize=(10, 6))
sorted_cols = match_df.isna().sum()[cols_with_na].sort_values(ascending=False).index

ax = sns.barplot(y=sorted_cols, x=match_df.isna().sum()[sorted_cols], orient='h', color="skyblue")

for i, v in enumerate(match_df.isna().sum()[sorted_cols]):
    ax.text(v + 50, i, f"{v / n_rows:.2%}", va='center', fontsize=10)

plt.xlabel('Количество пропущенных значений')
plt.ylabel('Столбцы')
plt.title('Пропущенные значения по столбцам')
plt.show()

# %% [markdown]
# ### Обработка пропусков

# %%
# удалим строки с пропусками, которые составляют менее 5%
threshold = 0.05
index = match_df.isna().mean() < threshold
columns_to_drop = index[index == True].index

match_df = match_df.dropna(subset=columns_to_drop)

# %%
# столбцы, в которых содержится более 5% пропусков
match_df[['series_id', 'series_type', 'throw', 'loss', 'comeback', 'stomp', 'radiant_logo', 'dire_logo']]
# Out:
#        series_id  series_type   throw     loss  comeback    stomp  \
# 0            NaN          NaN   571.0   8188.0       NaN      NaN
# 1            NaN          NaN     NaN      NaN    3347.0  22431.0
# 2       838321.0          1.0   348.0   7541.0       NaN      NaN
# 3       838323.0          1.0  2602.0  11185.0       NaN      NaN
# 4       838324.0          1.0     NaN      NaN    1361.0  29785.0
# ...          ...          ...     ...      ...       ...      ...
# 24699   921063.0          1.0     NaN      NaN       0.0  26663.0
# 24700   921063.0          1.0  2522.0  14885.0       NaN      NaN
# 24701   921081.0          1.0     NaN      NaN     463.0  20062.0
# 24702   921081.0          1.0     NaN      NaN    6576.0   9270.0
# 24703   921081.0          1.0     NaN      NaN      26.0  18429.0
#
#        radiant_logo     dire_logo
# 0      2.041868e+18  1.908989e+18
# 1      1.908989e+18  2.041868e+18
# 2      2.001336e+18  2.152217e+18
# 3      2.017089e+18  2.036224e+18
# 4      1.899975e+18  1.831290e+18
# ...             ...           ...
# 24699  2.460727e+18  1.914618e+18
# 24700  1.914618e+18  2.460727e+18
# 24701  2.045233e+18  2.431454e+18
# 24702  2.431454e+18  2.045233e+18
# 24703  2.045233e+18  2.431454e+18
#
# [21995 rows x 8 columns]

# %% [markdown]
# Описание столбцов с пропусками:
#
# * series_id (идентификатор серии матчей): возможно, информация о серии матчей не всегда фиксировалась или была доступна только для части матчей. Пропущенные значения можно заменить на модальное значение.
# * series_type (тип серии матча): аналогично series_id
# * throw (признак того, что одна из команд сознательно проиграла матч): по умолчанию можно считать, что если информация о бросании отсутствует, значит, команда не бросала игру. Никак не заменяем.
# * loss (признак поражения одной из команд): аналогично throw.Никак не заменяем.
# * comeback (признак камбека в матче): если информация о камбеке отсутствует, можно считать его не произошедшим и никак не изменять.
# * stomp (признак доминирования одной из команд над другой): аналогично comeback. Так же, как и для предыдущих полей, можно никак не изменять.
# * radiant_logo (логотип команды Radiant): логотип мог быть недоступен или не загружен на момент сохранения данных. Никак не заменяем.
# * dire_logo (логотип команды Dire): причины те же, что и для radiant_logo. Никак не заменяем.

# %%
fill_values = {
    'series_id': match_df['series_id'].mode()[0],
    'series_type': match_df['series_type'].mode()[0]
}

match_df.fillna(fill_values, inplace=True)
match_df.isna().sum()
# Out:
# match_id                       0
# barracks_status_dire           0
# barracks_status_radiant        0
# cluster                        0
# dire_score                     0
# duration                       0
# engine                         0
# first_blood_time               0
# game_mode                      0
# human_players                  0
# leagueid                       0
# lobby_type                     0
# match_seq_num                  0
# radiant_score                  0
# radiant_win                    0
# start_date_time                0
# tower_status_dire              0
# tower_status_radiant           0
# version                        0
# replay_salt                    0
# series_id                      0
# series_type                    0
# patch                          0
# region                         0
# throw                      10902
# loss                       10902
# comeback                   11094
# stomp                      11094
# replay_url                     0
# dire_team_id                   0
# radiant_team_id                0
# pre_game_duration              0
# flags                          0
# radiant_logo                3089
# radiant_team_complete          0
# dire_logo                   2827
# dire_team_complete             0
# radiant_captain                0
# dire_captain                   0
# dtype: int64

# %% [markdown]
# ### Расчет основных статистик

# %%
match_df.describe(include='all')
# Out:
#             match_id barracks_status_dire barracks_status_radiant  \
# count   2.199500e+04                21995                   21995
# unique           NaN                   51                      52
# top              NaN           '00111111'              '00111111'
# freq             NaN                11055                   11167
# mean    7.769170e+09                  NaN                     NaN
# std     1.439717e+08                  NaN                     NaN
# min     7.515635e+09                  NaN                     NaN
# 25%     7.645801e+09                  NaN                     NaN
# 50%     7.772006e+09                  NaN                     NaN
# 75%     7.894896e+09                  NaN                     NaN
# max     8.013424e+09                  NaN                     NaN
#
#              cluster    dire_score      duration   engine  first_blood_time  \
# count   21995.000000  21995.000000  21995.000000  21995.0      21995.000000
# unique           NaN           NaN           NaN      NaN               NaN
# top              NaN           NaN           NaN      NaN               NaN
# freq             NaN           NaN           NaN      NaN               NaN
# mean      238.217868     28.825188   1996.168811      1.0        126.099386
# std        52.943332     12.580393    563.734266      0.0        117.416147
# min       121.000000      0.000000    428.000000      1.0          0.000000
# 25%       184.000000     19.000000   1618.000000      1.0         18.000000
# 50%       271.000000     29.000000   1894.000000      1.0        109.000000
# 75%       273.000000     37.000000   2272.500000      1.0        189.000000
# max       347.000000     86.000000   6497.000000      1.0        971.000000
#
#            game_mode  human_players  ...  dire_team_id  radiant_team_id  \
# count   21995.000000   21995.000000  ...  2.199500e+04     2.199500e+04
# unique           NaN            NaN  ...           NaN              NaN
# top              NaN            NaN  ...           NaN              NaN
# freq             NaN            NaN  ...           NaN              NaN
# mean        2.029279       9.999773  ...  8.571129e+06     8.595441e+06
# std         0.639588       0.020227  ...  1.808271e+06     1.757884e+06
# min         2.000000       8.000000  ...  5.000000e+00     5.000000e+00
# 25%         2.000000      10.000000  ...  8.629318e+06     8.629318e+06
# 50%         2.000000      10.000000  ...  9.017006e+06     9.011000e+06
# 75%         2.000000      10.000000  ...  9.337731e+06     9.344338e+06
# max        16.000000      10.000000  ...  9.586712e+06     9.586554e+06
#
#         pre_game_duration         flags  radiant_logo radiant_team_complete  \
# count             21995.0  21995.000000  1.890600e+04          21995.000000
# unique                NaN           NaN           NaN                   NaN
# top                   NaN           NaN           NaN                   NaN
# freq                  NaN           NaN           NaN                   NaN
# mean                 90.0      3.519027  2.278090e+18              0.495294
# std                   0.0      1.803031  7.508606e+17              0.499989
# min                  90.0      0.000000  0.000000e+00              0.000000
# 25%                  90.0      4.000000  2.009201e+18              0.000000
# 50%                  90.0      4.000000  2.295212e+18              0.000000
# 75%                  90.0      5.000000  2.471990e+18              1.000000
# max                  90.0     12.000000  1.671736e+19              1.000000
#
#            dire_logo dire_team_complete  radiant_captain  dire_captain
# count   1.916800e+04       21995.000000     2.199500e+04  2.199500e+04
# unique           NaN                NaN              NaN           NaN
# top              NaN                NaN              NaN           NaN
# freq             NaN                NaN              NaN           NaN
# mean    2.284032e+18           0.497931     6.884535e+08  6.960917e+08
# std     7.435051e+17           0.500007     5.945779e+08  5.956410e+08
# min     0.000000e+00           0.000000     8.487180e+05  1.539190e+06
# 25%     2.017089e+18           0.000000     1.550564e+08  1.553325e+08
# 50%     2.295212e+18           0.000000     3.672178e+08  3.693425e+08
# 75%     2.470859e+18           1.000000     1.216609e+09  1.220632e+09
# max     1.843482e+19           1.000000     1.835306e+09  1.835306e+09
#
# [11 rows x 39 columns]

# %% [markdown]
# ### Описательная статистика

# %%
num_match_df = match_df[['match_id', 'cluster', 'dire_score', 'duration', 'game_mode', 
                        'human_players', 'leagueid', 'lobby_type', 'match_seq_num', 'radiant_score', 
                        'radiant_win', 'version', 'replay_salt', 'series_id', 'series_type', 
                        'patch', 'region', 'throw', 'loss', 'comeback', 'stomp', 'dire_team_id', 
                        'radiant_team_id', 'pre_game_duration', 'flags', 'radiant_logo', 
                        'radiant_team_complete', 'dire_logo', 'dire_team_complete', 
                        'radiant_captain', 'dire_captain']]
corr_matrix = num_match_df.corr()
corr_matrix
# Out:
#                        match_id   cluster  dire_score  duration  game_mode  \
# match_id               1.000000  0.147712   -0.022263 -0.070246  -0.068437
# cluster                0.147712  1.000000   -0.002439 -0.077271  -0.048556
# dire_score            -0.022263 -0.002439    1.000000  0.326693  -0.007987
# duration              -0.070246 -0.077271    0.326693  1.000000   0.040134
# game_mode             -0.068437 -0.048556   -0.007987  0.040134   1.000000
# human_players          0.015272  0.023397   -0.000692 -0.003828   0.000515
# leagueid               0.498648  0.016877   -0.166592  0.069603  -0.029097
# lobby_type                  NaN       NaN         NaN       NaN        NaN
# match_seq_num          0.999948  0.147765   -0.022089 -0.070523  -0.068436
# radiant_score         -0.033672 -0.021329    0.002232  0.264359  -0.002762
# radiant_win           -0.003600 -0.011690   -0.602682 -0.035975   0.005570
# version                     NaN       NaN         NaN       NaN        NaN
# replay_salt            0.009215  0.003934    0.003359 -0.011718  -0.010638
# series_id              0.246461  0.011456   -0.006672 -0.015113   0.040541
# series_type            0.069267  0.038375   -0.046489  0.109335  -0.005916
# patch                  0.922125  0.114313   -0.029145 -0.074669  -0.043659
# region                -0.049897  0.075768   -0.035827  0.105159   0.018041
# throw                 -0.005663  0.067148    0.568390  0.478329  -0.006105
# loss                  -0.055073 -0.187497   -0.330856  0.020208   0.021717
# comeback              -0.014913  0.066137    0.031680  0.381050   0.003764
# stomp                 -0.046202 -0.185759    0.256996  0.152886   0.023206
# dire_team_id           0.023031 -0.034922    0.067098 -0.069047   0.014915
# radiant_team_id        0.031183 -0.025327    0.079777 -0.067977   0.014383
# pre_game_duration           NaN       NaN         NaN       NaN        NaN
# flags                  0.076805  0.045079   -0.161322 -0.342983  -0.034154
# radiant_logo           0.091189 -0.009694    0.036454 -0.029976   0.000711
# radiant_team_complete  0.092499  0.313349   -0.111206 -0.044269  -0.045351
# dire_logo              0.078673  0.039606    0.014720 -0.008609  -0.000194
# dire_team_complete     0.095942  0.305079   -0.095877 -0.040487  -0.045591
# radiant_captain        0.069092  0.196370    0.153178 -0.212193  -0.042646
# dire_captain           0.073972  0.194440    0.131361 -0.209570  -0.040573
#
#                        human_players  leagueid  lobby_type  match_seq_num  \
# match_id                    0.015272  0.498648         NaN       0.999948
# cluster                     0.023397  0.016877         NaN       0.147765
# dire_score                 -0.000692 -0.166592         NaN      -0.022089
# duration                   -0.003828  0.069603         NaN      -0.070523
# game_mode                   0.000515 -0.029097         NaN      -0.068436
# human_players               1.000000  0.004890         NaN       0.015267
# leagueid                    0.004890  1.000000         NaN       0.498597
# lobby_type                       NaN       NaN         NaN            NaN
# match_seq_num               0.015267  0.498597         NaN       1.000000
# radiant_score               0.017190 -0.165270         NaN      -0.033591
# radiant_win                 0.006842  0.000183         NaN      -0.003668
# version                          NaN       NaN         NaN            NaN
# replay_salt                 0.003320  0.001644         NaN       0.009382
# series_id                  -0.009953  0.102048         NaN       0.244892
# series_type                 0.001452  0.227657         NaN       0.069319
# patch                       0.010718  0.444248         NaN       0.920893
# region                      0.005537  0.083415         NaN      -0.049764
# throw                       0.004151 -0.035856         NaN      -0.005736
# loss                        0.019425  0.057521         NaN      -0.055139
# comeback                    0.013304 -0.035641         NaN      -0.015079
# stomp                      -0.042456  0.065628         NaN      -0.046381
# dire_team_id               -0.004585 -0.126487         NaN       0.022928
# radiant_team_id             0.006817 -0.116381         NaN       0.031188
# pre_game_duration                NaN       NaN         NaN            NaN
# flags                       0.011962  0.054324         NaN       0.078689
# radiant_logo                0.000578 -0.001902         NaN       0.091376
# radiant_team_complete       0.011133  0.200438         NaN       0.092740
# dire_logo                   0.000220 -0.004757         NaN       0.079038
# dire_team_complete          0.011192  0.207474         NaN       0.096170
# radiant_captain             0.010184 -0.289028         NaN       0.069445
# dire_captain                0.010363 -0.284220         NaN       0.074415
#
#                        radiant_score  ...  dire_team_id  radiant_team_id  \
# match_id                   -0.033672  ...      0.023031         0.031183
# cluster                    -0.021329  ...     -0.034922        -0.025327
# dire_score                  0.002232  ...      0.067098         0.079777
# duration                    0.264359  ...     -0.069047        -0.067977
# game_mode                  -0.002762  ...      0.014915         0.014383
# human_players               0.017190  ...     -0.004585         0.006817
# leagueid                   -0.165270  ...     -0.126487        -0.116381
# lobby_type                       NaN  ...           NaN              NaN
# match_seq_num              -0.033591  ...      0.022928         0.031188
# radiant_score               1.000000  ...      0.090521         0.072606
# radiant_win                 0.574318  ...      0.018289        -0.007734
# version                          NaN  ...           NaN              NaN
# replay_salt                -0.004801  ...     -0.006019        -0.002888
# series_id                  -0.007671  ...      0.021878         0.010032
# series_type                -0.061505  ...     -0.096893        -0.095971
# patch                      -0.039279  ...      0.037309         0.038253
# region                     -0.026397  ...     -0.009405         0.009405
# throw                       0.047083  ...     -0.003976         0.022271
# loss                        0.249848  ...     -0.027231        -0.032761
# comeback                    0.544623  ...      0.018624        -0.010251
# stomp                      -0.296738  ...     -0.052898        -0.042216
# dire_team_id                0.090521  ...      1.000000         0.082468
# radiant_team_id             0.072606  ...      0.082468         1.000000
# pre_game_duration                NaN  ...           NaN              NaN
# flags                      -0.155699  ...      0.000256         0.004639
# radiant_logo                0.017517  ...      0.035661         0.094655
# radiant_team_complete      -0.116648  ...     -0.181953        -0.147604
# dire_logo                   0.011494  ...     -0.014414         0.017731
# dire_team_complete         -0.145396  ...     -0.155861        -0.186398
# radiant_captain             0.121238  ...      0.114017         0.155419
# dire_captain                0.137795  ...      0.142121         0.116405
#
#                        pre_game_duration     flags  radiant_logo  \
# match_id                             NaN  0.076805      0.091189
# cluster                              NaN  0.045079     -0.009694
# dire_score                           NaN -0.161322      0.036454
# duration                             NaN -0.342983     -0.029976
# game_mode                            NaN -0.034154      0.000711
# human_players                        NaN  0.011962      0.000578
# leagueid                             NaN  0.054324     -0.001902
# lobby_type                           NaN       NaN           NaN
# match_seq_num                        NaN  0.078689      0.091376
# radiant_score                        NaN -0.155699      0.017517
# radiant_win                          NaN -0.001114     -0.019885
# version                              NaN       NaN           NaN
# replay_salt                          NaN  0.015488     -0.000031
# series_id                            NaN -0.073488     -0.045844
# series_type                          NaN  0.018928     -0.018873
# patch                                NaN  0.038502      0.066145
# region                               NaN -0.042689     -0.034511
# throw                                NaN -0.211165      0.005060
# loss                                 NaN  0.031144     -0.006893
# comeback                             NaN -0.173880     -0.021581
# stomp                                NaN -0.029819     -0.018057
# dire_team_id                         NaN  0.000256      0.035661
# radiant_team_id                      NaN  0.004639      0.094655
# pre_game_duration                    NaN       NaN           NaN
# flags                                NaN  1.000000      0.016435
# radiant_logo                         NaN  0.016435      1.000000
# radiant_team_complete                NaN  0.060205      0.042435
# dire_logo                            NaN  0.026510      0.013051
# dire_team_complete                   NaN  0.067006     -0.042330
# radiant_captain                      NaN  0.016550      0.076559
# dire_captain                         NaN  0.015565      0.072044
#
#                        radiant_team_complete  dire_logo  dire_team_complete  \
# match_id                            0.092499   0.078673            0.095942
# cluster                             0.313349   0.039606            0.305079
# dire_score                         -0.111206   0.014720           -0.095877
# duration                           -0.044269  -0.008609           -0.040487
# game_mode                          -0.045351  -0.000194           -0.045591
# human_players                       0.011133   0.000220            0.011192
# leagueid                            0.200438  -0.004757            0.207474
# lobby_type                               NaN        NaN                 NaN
# match_seq_num                       0.092740   0.079038            0.096170
# radiant_score                      -0.116648   0.011494           -0.145396
# radiant_win                         0.002765   0.006374           -0.027108
# version                                  NaN        NaN                 NaN
# replay_salt                         0.002682  -0.006080           -0.004132
# series_id                          -0.002146  -0.066474           -0.001552
# series_type                         0.160824   0.010507            0.164792
# patch                               0.074904   0.044012            0.076571
# region                             -0.135679  -0.002907           -0.146762
# throw                               0.016635   0.003985            0.009308
# loss                               -0.112289  -0.016943           -0.114454
# comeback                            0.016954  -0.019888            0.004297
# stomp                              -0.095334   0.008970           -0.092426
# dire_team_id                       -0.181953  -0.014414           -0.155861
# radiant_team_id                    -0.147604   0.017731           -0.186398
# pre_game_duration                        NaN        NaN                 NaN
# flags                               0.060205   0.026510            0.067006
# radiant_logo                        0.042435   0.013051           -0.042330
# radiant_team_complete               1.000000  -0.018192            0.493872
# dire_logo                          -0.018192   1.000000            0.058019
# dire_team_complete                  0.493872   0.058019            1.000000
# radiant_captain                    -0.014801   0.077718           -0.018097
# dire_captain                       -0.010187   0.062997           -0.022114
#
#                        radiant_captain  dire_captain
# match_id                      0.069092      0.073972
# cluster                       0.196370      0.194440
# dire_score                    0.153178      0.131361
# duration                     -0.212193     -0.209570
# game_mode                    -0.042646     -0.040573
# human_players                 0.010184      0.010363
# leagueid                     -0.289028     -0.284220
# lobby_type                         NaN           NaN
# match_seq_num                 0.069445      0.074415
# radiant_score                 0.121238      0.137795
# radiant_win                  -0.021459     -0.004188
# version                            NaN           NaN
# replay_salt                   0.003992      0.001369
# series_id                    -0.013400     -0.014178
# series_type                  -0.132669     -0.132804
# patch                         0.043335      0.050416
# region                       -0.166173     -0.161947
# throw                         0.061970      0.014381
# loss                         -0.192897     -0.160244
# comeback                      0.011050      0.039966
# stomp                        -0.186333     -0.206734
# dire_team_id                  0.114017      0.142121
# radiant_team_id               0.155419      0.116405
# pre_game_duration                  NaN           NaN
# flags                         0.016550      0.015565
# radiant_logo                  0.076559      0.072044
# radiant_team_complete        -0.014801     -0.010187
# dire_logo                     0.077718      0.062997
# dire_team_complete           -0.018097     -0.022114
# radiant_captain               1.000000      0.523069
# dire_captain                  0.523069      1.000000
#
# [31 rows x 31 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 8))
mask = np.zeros_like(corr_matrix, dtype=bool)
mask[np.triu(corr_matrix) != 0] = True
sns.heatmap(data=corr_matrix, annot=True, cmap='coolwarm', center=0, square=True, cbar_kws={"shrink": 0.75}, fmt='.2f', annot_kws={'size': 6})
plt.title('Матрица корреляционного анализа')
plt.tight_layout()
plt.show()

# %%
target = 'radiant_win'
correlations = abs(corr_matrix[target])
top_correlations = correlations.sort_values(ascending=False)
top_correlations[:10]
# Out:
# radiant_win           1.000000
# dire_score            0.602682
# radiant_score         0.574318
# duration              0.035975
# dire_team_complete    0.027108
# radiant_captain       0.021459
# radiant_logo          0.019885
# dire_team_id          0.018289
# cluster               0.011690
# radiant_team_id       0.007734
# Name: radiant_win, dtype: float64

# %%
mean_duration = match_df.groupby('radiant_win')['duration'].mean()
mean_duration.plot(kind='bar', color=['red', 'blue'], figsize=(8, 5))
plt.title('Средняя продолжительность матча по победам')
plt.xlabel('Результат')
plt.ylabel('Средняя продолжительность (в секундах)')
plt.xticks([0, 1], ['Dire Win', 'Radiant Win'], rotation=0)
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

sns.histplot(data=match_df, x='radiant_score', hue='radiant_win', multiple='stack', 
             kde=True, palette='light:b', bins=30)
plt.title('Распределение очков Radiant')
plt.xlabel('Очки Radiant')
plt.ylabel('Количество матчей')
plt.show()

# %%
region_wins = match_df.groupby(['region', 'radiant_win']).size().unstack()
region_wins.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Победы по регионам')
plt.xlabel('Регион')
plt.ylabel('Количество матчей')
plt.legend(title='Результат')
plt.show()

# %% [markdown]
# ### Оставим в датасете только те столбцы, которые могут влиять на результат матча:

# %%
match_df = match_df[['match_id', 'barracks_status_dire', 'barracks_status_radiant', 'dire_score',
                     'radiant_score', 'duration', 'first_blood_time', 'game_mode', 'human_players',
                     'lobby_type', 'radiant_win', 'tower_status_dire', 'tower_status_radiant', 
                     'throw', 'loss', 'comeback', 'stomp', 'pre_game_duration']]
match_df.head()
# Out:
#      match_id barracks_status_dire barracks_status_radiant  dire_score  \
# 0  7515635423           '00110100'              '00111111'          26
# 1  7515660161           '00111111'              '00001111'          43
# 2  7515737711           '00111101'              '00111111'          25
# 3  7515745579           '00110011'              '00111111'          31
# 4  7515769503           '00111111'              '00000000'          21
#
#    radiant_score  duration  first_blood_time  game_mode  human_players  \
# 0             42      1926               140          2             10
# 1             18      1731               121          2             10
# 2             35      2056                84          2             10
# 3             51      2221                28          2             10
# 4             11      1998               264          2             10
#
#    lobby_type radiant_win   tower_status_dire tower_status_radiant   throw  \
# 0           1        True  '0000000110000000'   '0000011110110111'   571.0
# 1           1       False  '0000011111110110'   '0000011000100111'     NaN
# 2           1        True  '0000011100100000'   '0000011110110111'   348.0
# 3           1        True  '0000010110000110'   '0000011100110100'  2602.0
# 4           1       False  '0000011111110110'   '0000000000000000'     NaN
#
#       loss  comeback    stomp  pre_game_duration
# 0   8188.0       NaN      NaN               90.0
# 1      NaN    3347.0  22431.0               90.0
# 2   7541.0       NaN      NaN               90.0
# 3  11185.0       NaN      NaN               90.0
# 4      NaN    1361.0  29785.0               90.0

# %%
win_counts = match_df['radiant_win'].value_counts()
win_counts.plot(kind='bar', color=['blue', 'red'])
plt.title('Распределение побед Radiant и Dire')
plt.xlabel('Победа')
plt.ylabel('Количество матчей')
plt.xticks(ticks=[0, 1], labels=['Dire', 'Radiant'], rotation=0)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='radiant_win', y='duration', data=match_df)
plt.title('Продолжительность матчей в зависимости от победы')
plt.xlabel('Победа (0 - Dire, 1 - Radiant)')
plt.ylabel('Продолжительность (в секундах)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(match_df['first_blood_time'], bins=30, kde=True)
plt.title('Распределение времени первой крови')
plt.xlabel('Время первой крови (в секундах)')
plt.ylabel('Количество матчей')
plt.show()

# %%
sns.set(style="whitegrid")

for column in match_df.columns:
    plt.figure(figsize=(10, 6))
    
    if pd.api.types.is_numeric_dtype(match_df[column]):
        sns.histplot(match_df[column], bins=30, kde=False)
        plt.title(f'Гистограмма для {column}')
        plt.xlabel(column)
        plt.ylabel('Количество')
    else:
        value_counts = match_df[column].value_counts()
        sns.barplot(x=value_counts.index.astype(str), y=value_counts.values)
        plt.title(f'Bar Plot для {column}')
        plt.xlabel(column)
        plt.ylabel('Количество')
        plt.xticks(rotation=45)
    
    plt.show()

# %%
match_df = match_df[match_df['game_mode'] == 2]
match_df = match_df[match_df['human_players'] == 10]
match_df = match_df[match_df['lobby_type'] == 1]

# %% [markdown]
# ### Почистим датасет *players_df* и объединим с *match_df*

# %%
players_df.columns.to_list()
# Out:
# ['match_id',
#  'player_slot',
#  'ability_targets',
#  'ability_upgrades_arr',
#  'ability_uses',
#  'account_id',
#  'actions',
#  'additional_units',
#  'assists',
#  'backpack_0',
#  'backpack_1',
#  'backpack_2',
#  'backpack_3',
#  'buyback_log',
#  'camps_stacked',
#  'connection_log',
#  'creeps_stacked',
#  'damage',
#  'damage_inflictor',
#  'damage_inflictor_received',
#  'damage_taken',
#  'damage_targets',
#  'deaths',
#  'denies',
#  'dn_t',
#  'firstblood_claimed',
#  'gold',
#  'gold_per_min',
#  'gold_reasons',
#  'gold_spent',
#  'gold_t',
#  'hero_damage',
#  'hero_healing',
#  'hero_hits',
#  'hero_id',
#  'item_0',
#  'item_1',
#  'item_2',
#  'item_3',
#  'item_4',
#  'item_5',
#  'item_neutral',
#  'item_uses',
#  'kill_streaks',
#  'killed',
#  'killed_by',
#  'kills',
#  'kills_log',
#  'lane_pos',
#  'last_hits',
#  'leaver_status',
#  'level',
#  'lh_t',
#  'life_state',
#  'max_hero_hit',
#  'multi_kills',
#  'net_worth',
#  'obs',
#  'obs_left_log',
#  'obs_log',
#  'obs_placed',
#  'party_id',
#  'party_size',
#  'performance_others',
#  'permanent_buffs',
#  'pings',
#  'pred_vict',
#  'purchase',
#  'purchase_log',
#  'randomed',
#  'repicked',
#  'roshans_killed',
#  'rune_pickups',
#  'runes',
#  'runes_log',
#  'sen',
#  'sen_left_log',
#  'sen_log',
#  'sen_placed',
#  'stuns',
#  'teamfight_participation',
#  'times',
#  'tower_damage',
#  'towers_killed',
#  'xp_per_min',
#  'xp_reasons',
#  'xp_t',
#  'personaname',
#  'name',
#  'last_login',
#  'radiant_win',
#  'start_time',
#  'duration',
#  'cluster',
#  'lobby_type',
#  'game_mode',
#  'is_contributor',
#  'patch',
#  'isRadiant',
#  'win',
#  'lose',
#  'total_gold',
#  'total_xp',
#  'kills_per_min',
#  'kda',
#  'abandons',
#  'neutral_kills',
#  'tower_kills',
#  'courier_kills',
#  'lane_kills',
#  'hero_kills',
#  'observer_kills',
#  'sentry_kills',
#  'roshan_kills',
#  'necronomicon_kills',
#  'ancient_kills',
#  'buyback_count',
#  'observer_uses',
#  'sentry_uses',
#  'lane_efficiency',
#  'lane_efficiency_pct',
#  'lane',
#  'lane_role',
#  'is_roaming',
#  'purchase_time',
#  'first_purchase_time',
#  'item_win',
#  'item_usage',
#  'purchase_ward_sentry',
#  'purchase_tpscroll',
#  'actions_per_min',
#  'life_state_dead',
#  'rank_tier',
#  'is_subscriber',
#  'cosmetics',
#  'benchmarks',
#  'purchase_ward_observer',
#  'leagueid',
#  'region',
#  'purchase_gem',
#  'purchase_rapier',
#  'observers_placed',
#  'healing',
#  'team_number',
#  'team_slot',
#  'aghanims_scepter',
#  'aghanims_shard',
#  'moonshard',
#  'hero_variant',
#  'neutral_tokens_log']

# %%
selected_columns = [
    'match_id',
    'duration',
    'game_mode',
    'start_time',
    'radiant_win',
    'hero_id',
    'player_slot',
    'kills',
    'deaths',
    'assists',
    'gold_per_min',
    'xp_per_min',
    'last_hits',
    'denies',
    'level',
    'hero_damage',
    'item_0',
    'item_1',
    'item_2',
    'item_3',
    'item_4',
    'item_5'
]

players_df = players_df[selected_columns]
players_df.head()
# Out:
#      match_id duration game_mode  start_time radiant_win hero_id player_slot  \
# 0  7515635423     1926         2  1704068656        True   107.0           0
# 1  7515635423     1926         2  1704068656        True    10.0           1
# 2  7515635423     1926         2  1704068656        True    79.0           2
# 3  7515635423     1926         2  1704068656        True    83.0           3
# 4  7515635423     1926         2  1704068656        True    11.0           4
#
#   kills deaths assists  ... last_hits denies level hero_damage item_0 item_1  \
# 0   8.0    7.0    21.0  ...     176.0    7.0  20.0     32753.0  116.0  119.0
# 1  11.0    3.0     6.0  ...     233.0    8.0  24.0     26629.0   36.0   75.0
# 2   7.0    4.0    18.0  ...     118.0    4.0  17.0     13047.0  218.0  100.0
# 3  11.0    8.0    19.0  ...      29.0    1.0  21.0     19712.0   34.0  180.0
# 4   5.0    4.0     4.0  ...     346.0    1.0  21.0     14358.0  236.0   63.0
#
#    item_2 item_3  item_4 item_5
# 0    92.0  127.0    36.0   29.0
# 1  1808.0   63.0   123.0  160.0
# 2   232.0  180.0  4206.0  108.0
# 3   226.0  218.0     1.0  188.0
# 4   147.0  149.0    41.0  116.0
#
# [5 rows x 22 columns]

# %%
players_df.describe(include='all')
# Out:
#           match_id duration game_mode  start_time radiant_win hero_id  \
# count       246515   246515    246515      246515      246508  246515
# unique       24704     4242         8       24665           4     372
# top     7515635423     1748         2  1720960200        True    86.0
# freq            10      320    219715          30      114959    3386
#
#        player_slot   kills  deaths assists  ... last_hits  denies   level  \
# count       246515  246515  246515  246515  ...    246515  246515  246515
# unique          20     107      74     152  ...      2656     167      87
# top              0     2.0     5.0     8.0  ...       0.0     1.0    18.0
# freq         22393   14235   14282    6953  ...       909   15543    9649
#
#        hero_damage  item_0  item_1  item_2  item_3  item_4  item_5
# count       246515  246515  246515  246515  246515  246515  246515
# unique       91584     574     575     577     586     580     595
# top            0.0     1.0     1.0    36.0    36.0    36.0     0.0
# freq           873   10922   10550   11905    9504   10010   13577
#
# [4 rows x 22 columns]

# %%
players_df['radiant_win'].unique()
# Out:
# array(['True', 'False', nan, True, False], dtype=object)

# %%
players_df = players_df[players_df['radiant_win'].isin([True, False])]
players_df = players_df[players_df['game_mode'] == 2]

# %%
players_df.isna().sum()
# Out:
# match_id        0
# duration        0
# game_mode       0
# start_time      0
# radiant_win     0
# hero_id         0
# player_slot     0
# kills           0
# deaths          0
# assists         0
# gold_per_min    0
# xp_per_min      0
# last_hits       0
# denies          0
# level           0
# hero_damage     0
# item_0          0
# item_1          0
# item_2          0
# item_3          0
# item_4          0
# item_5          0
# dtype: int64

# %%
merged_df = pd.merge(match_df, players_df, on='match_id', how='inner')
merged_df.head()
# Out:
#      match_id barracks_status_dire barracks_status_radiant  dire_score  \
# 0  7967560450           '00110011'              '00111111'          34
# 1  7967560450           '00110011'              '00111111'          34
# 2  7967560450           '00110011'              '00111111'          34
# 3  7967560450           '00110011'              '00111111'          34
# 4  7967560450           '00110011'              '00111111'          34
#
#    radiant_score  duration_x  first_blood_time  game_mode_x  human_players  \
# 0             35        2233               129            2             10
# 1             35        2233               129            2             10
# 2             35        2233               129            2             10
# 3             35        2233               129            2             10
# 4             35        2233               129            2             10
#
#    lobby_type  ... last_hits denies level  hero_damage  item_0  item_1  \
# 0           1  ...        95      1    21         8331       1     100
# 1           1  ...        11      1    17        11850     102     206
# 2           1  ...       259      6    24        20036      50       1
# 3           1  ...       417      0    27        30281      48      96
# 4           1  ...       446      5    28        42770     603     156
#
#    item_2  item_3 item_4 item_5
# 0      40     180     21      0
# 1      77      36     40    180
# 2     116     108    235    119
# 3     203     176    235    244
# 4      50     116    208    145
#
# [5 rows x 39 columns]

# %%
merged_df.columns
# Out:
# Index(['match_id', 'barracks_status_dire', 'barracks_status_radiant',
#        'dire_score', 'radiant_score', 'duration_x', 'first_blood_time',
#        'game_mode_x', 'human_players', 'lobby_type', 'radiant_win_x',
#        'tower_status_dire', 'tower_status_radiant', 'throw', 'loss',
#        'comeback', 'stomp', 'pre_game_duration', 'duration_y', 'game_mode_y',
#        'start_time', 'radiant_win_y', 'hero_id', 'player_slot', 'kills',
#        'deaths', 'assists', 'gold_per_min', 'xp_per_min', 'last_hits',
#        'denies', 'level', 'hero_damage', 'item_0', 'item_1', 'item_2',
#        'item_3', 'item_4', 'item_5'],
#       dtype='object')

# %% [markdown]
# # Описание полей в Dota 2 датасете
#
# | Поле                        | Тип       | Описание                                                                                  |
# |-----------------------------|-----------|-------------------------------------------------------------------------------------------|
# | `match_id`                  | Integer   | Уникальный идентификатор матча.                                                           |
# | `barracks_status_dire`      | Integer   | Состояние бараков команды Dire (0 - все живые, 1 - один разрушен, 2 - оба разрушены).   |
# | `barracks_status_radiant`   | Integer   | Состояние бараков команды Radiant (0 - все живые, 1 - один разрушен, 2 - оба разрушены).|
# | `dire_score`                | Integer   | Очки команды Dire по окончании матча.                                                    |
# | `radiant_score`             | Integer   | Очки команды Radiant по окончании матча.                                                |
# | `duration_x`                | Integer   | Продолжительность матча в секундах (версия X).                                          |
# | `first_blood_time`          | Integer   | Время, когда произошло первое убийство (в секундах).                                     |
# | `game_mode_x`               | Integer   | Режим игры (например, 1 для "All Pick", 2 для "Captain's Mode" и т.д., версия X).     |
# | `human_players`             | Integer   | Общее количество игроков-людей в игре.                                                   |
# | `lobby_type`                | Integer   | Тип лобби (например, 0 для обычного, 1 для рейтингового и т.д.).                       |
# | `radiant_win_x`             | Boolean   | Указывает, выиграла ли команда Radiant в версии X (True или False).                     |
# | `tower_status_dire`         | Integer   | Состояние башен команды Dire (0 - все живые, 1 - одна разрушена, 2 - две разрушены и т.д.). |
# | `tower_status_radiant`      | Integer   | Состояние башен команды Radiant (0 - все живые, 1 - одна разрушена, 2 - две разрушены и т.д.). |
# | `throw`                     | Boolean   | Указывает, произошла ли "потеря" преимущества.                                           |
# | `loss`                      | Boolean   | Указывает, проиграла ли команда (True - проиграла, False - выиграла).                   |
# | `comeback`                  | Boolean   | Указывает, произошло ли "возвращение" команды после отставания.                         |
# | `stomp`                     | Boolean   | Указывает, был ли матч "накатанным" (одна команда доминировала).                        |
# | `pre_game_duration`         | Integer   | Продолжительность подготовки перед матчем в секундах.                                    |
# | `duration_y`                | Integer   | Продолжительность матча в секундах (версия Y).                                          |
# | `game_mode_y`               | Integer   | Режим игры (версия Y).                                                                    |
# | `start_time`                | Integer   | Время начала матча в формате UNIX timestamp.                                             |
# | `radiant_win_y`             | Boolean   | Указывает, выиграла ли команда Radiant в версии Y (True или False).                     |
# | `hero_id`                   | Integer   | Уникальный идентификатор героя, выбранного игроком.                                     |
# | `player_slot`               | Integer   | Номер слота игрока (0-4 для Radiant и 128-132 для Dire).                               |
# | `kills`                     | Integer   | Общее количество убийств, совершенных игроком в матче.                                   |
# | `deaths`                    | Integer   | Общее количество смертей игрока в матче.                                                 |
# | `assists`                   | Integer   | Общее количество помощей, оказанных игроком в матче.                                     |кретной задачи.
